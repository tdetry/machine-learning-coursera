# %% [markdown]
# This notebook is about the comprehenstion of **forward** propagation in Neural Network. What we've learn is that Neural Network is a magical tool to represent non-linear functions.

# %%
from IPython.display import Image
from IPython.core.display import HTML 
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd
import scipy.io as sio

# %%
Image(filename = "./network.png", width=400)

# %%
data = sio.loadmat('./data/ex3data1.mat')
theta = sio.loadmat('./data/ex3weights.mat')

# %%
X = data['X']
X.shape
# Out:
# (5000, 400)

# %%
y = data['y']
n = len(y)
y = y.reshape(n)
y.shape
# Out:
# (5000,)

# %%
theta1 = theta['Theta1']
theta2 = theta['Theta2']
print(theta1.shape)
print(theta2.shape)
# Out:
# (25, 401)
# (10, 26)

# %%
def show_image(x):
    digit = x.reshape(20,20, order='F')
    plt.imshow(digit, cmap='gray')
    plt.show()

# %%
show_image(X[0])

# %%
def sigmoid(x):                                        
    return 1.0 / (1 + np.exp(-x))

# %%
def predict(theta1, theta2, x):
    # intercept
    x = np.insert(x, 0, 1)
    x = x.reshape((x.shape[0], 1))

    z2 = theta1 @ x
    a2 = sigmoid(z2)
    
    #bias
    a2 = np.insert(a2, 0, 1, axis=0)
    
    z3 = theta2 @ a2
    a3 = sigmoid(z3)
    
    y = np.argmax(a3) + 1
    
    return y

# %%
y_pred = [predict(theta1, theta2, i) for i in X]

# %%
print(classification_report(y, y_pred, labels=np.unique(y)))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.98       500
#            2       0.98      0.97      0.98       500
#            3       0.98      0.96      0.97       500
#            4       0.97      0.97      0.97       500
#            5       0.97      0.98      0.98       500
#            6       0.98      0.99      0.98       500
#            7       0.98      0.97      0.97       500
#            8       0.98      0.98      0.98       500
#            9       0.97      0.96      0.96       500
#           10       0.98      0.99      0.99       500
#
#    micro avg       0.98      0.98      0.98      5000
#    macro avg       0.98      0.98      0.98      5000
# weighted avg       0.98      0.98      0.98      5000
